# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import csv
import re
import urllib.request as urllib2
from datetime import datetime
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
url='https://en.wikipedia.org/wiki/Healthcare_in_Europe'
r=requests.get(url)
HCE=BeautifulSoup(r.text)
type(HCE)
# Out:
# bs4.BeautifulSoup

# %%
r
# Out:
# <Response [200]>

# %%
HCE
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Healthcare in Europe - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"ed6a519b-7f3c-46fb-a177-4ed701874d04","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Healthcare_in_Europe","wgTitle":"Healthcare in Europe","wgCurRevisionId":1131475728,"wgRevisionId":1131475728,"wgArticleId":15973120,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: url-status","Use dmy dates from December 2021","All articles with unsourced statements","Articles with unsourced statements from January 2021","Articles with unsourced statements from September 2022","Articles with LCCN identifiers","Health in Europe"],
# "wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Healthcare_in_Europe","wgRelevantArticleId":15973120,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q5691262","GEHomepageSuggestedEditsEnableTopics":true,
# "wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","skins.vector.es6","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging",
# "ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.cx.uls.quick.actions","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.ui.button%2Cicon%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <meta content="MediaWiki 1.40.0-wmf.19" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="751" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/800px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="501" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/640px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="401" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="Healthcare in Europe - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Healthcare_in_Europe" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://en.wikipedia.org/wiki/Healthcare_in_Europe" rel="canonical"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="skin-vector skin-vector-search-vue vector-toc-pinned mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Healthcare_in_Europe rootpage-Healthcare_in_Europe skin-vector-2022 action-view vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-sticky-header-edit-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled"><div class="mw-page-container">
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="mw-page-container-inner">
# <input class="mw-checkbox-hack-checkbox" id="mw-sidebar-checkbox" type="checkbox"/>
# <header class="mw-header mw-ui-icon-flush-left mw-ui-icon-flush-right">
# <div class="vector-header-start">
# <label aria-controls="mw-panel" class="mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-flush-right" data-event-name="ui.sidebar" for="mw-sidebar-checkbox" id="mw-sidebar-button" role="button" tabindex="0" title="Main menu">
# <span>Toggle sidebar</span>
# </label>
# <a class="mw-logo" href="/wiki/Main_Page">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="mw-ui-button mw-ui-quiet mw-ui-icon mw-ui-icon-element mw-ui-icon-wikimedia-search search-toggle" href="/wiki/Special:Search" title="Search Wikipedia [f]">
# <span>Search</span>
# </a>
# <div>
# <form action="/w/index.php" class="vector-search-box-form" id="searchform">
# <div class="vector-search-box-inner" data-search-loc="header-moved" id="simpleSearch">
# <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="vector-search-box-input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# <input name="title" type="hidden" value="Special:Search"/>
# <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
# <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
# </div>
# </form>
# </div>
# </div>
# <nav aria-label="Personal tools" class="vector-user-links" role="navigation">
# <div class="vector-menu mw-portlet mw-portlet-vector-user-menu-overflow" id="p-vector-user-menu-overflow">
# <div class="vector-menu-heading">
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="user-links-collapsible-item mw-list-item" id="pt-createaccount-2"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Healthcare+in+Europe" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-personal vector-user-menu vector-user-menu-logged-out" id="p-personal" title="More options">
# <input aria-haspopup="true" class="vector-menu-checkbox" data-event-name="ui.dropdown-p-personal" id="p-personal-checkbox" role="button" type="checkbox"/>
# <label class="vector-menu-heading mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-wikimedia-ellipsis" for="p-personal-checkbox" id="p-personal-label">
# <span class="vector-menu-heading-label">Foo</span>
# </label>
# <div class="vector-menu-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="vector-user-menu-create-account user-links-collapsible-item"><a data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=Healthcare+in+Europe"><span class="mw-ui-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span><span>Create account</span></a>
# </li><li class="vector-user-menu-login"><a accesskey="o" data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=Healthcare+in+Europe" title="[o]"><span class="mw-ui-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span><span>Log in</span></a>
# </li></ul>
# </div>
# <div class="vector-user-menu-anon-editor">
# <p>
# 				Pages for logged out editors <a aria-label="Learn more about editing" data-mw="interface" href="/wiki/Help:Introduction"><span>learn more</span></a>
# </p>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]"><span>Talk</span></a></li><li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a></li></ul>
# </div>
# </div>
# </div></nav>
# </div>
# </header>
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel" role="navigation">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-main-menu-group vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Navigation</span>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li></ul>
# </div>
# </div>
# <div class="vector-main-menu-group vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
# <div class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li></ul>
# </div>
# </div>
# <div class="vector-main-menu-group vector-menu mw-portlet mw-portlet-tb" id="p-tb">
# <div class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Healthcare_in_Europe" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Healthcare_in_Europe" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Healthcare_in_Europe&amp;id=1131475728&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q5691262" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a></li></ul>
# </div>
# </div>
# <div class="vector-main-menu-group vector-menu mw-portlet mw-portlet-coll-print_export" id="p-coll-print_export">
# <div class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Healthcare_in_Europe&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Healthcare_in_Europe&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a></li></ul>
# </div>
# </div>
# <div class="vector-main-menu-action vector-main-menu-action-lang-alert">
# <div class="vector-main-menu-action-item">
# <div class="vector-main-menu-action-heading vector-menu-heading">Languages</div>
# <div class="vector-main-menu-action-content vector-menu-content">
# <div class="mw-message-box-notice vector-language-sidebar-alert mw-message-box">On this Wikipedia the language links are at the top of the page across from the article title. <a href="#p-lang-btn">Go to top</a>.</div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sitenotice-container">
# <div id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <input class="mw-checkbox-hack-checkbox" id="vector-toc-collapsed-checkbox" type="checkbox"/>
# <nav aria-label="Contents" class="mw-table-of-contents-container" data-event-name="ui.sidebar-toc" id="mw-panel-toc" role="navigation">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-name="vector-toc">
# <h2 class="vector-pinnable-header-label">Contents</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">(Top)</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-European_health">
# <a class="vector-toc-link" href="#European_health">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>European health</div>
# </a>
# <button aria-controls="toc-European_health-sublist" class="mw-ui-icon mw-ui-icon-wikimedia-expand mw-ui-icon-small vector-toc-toggle">
# </button>
# <ul class="vector-toc-list" id="toc-European_health-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-European_Union">
# <a class="vector-toc-link" href="#European_Union">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.1</span>European Union</div>
# </a>
# <ul class="vector-toc-list" id="toc-European_Union-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-COVID-19_pandemic">
# <a class="vector-toc-link" href="#COVID-19_pandemic">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.2</span>COVID-19 pandemic</div>
# </a>
# <ul class="vector-toc-list" id="toc-COVID-19_pandemic-sublist">
# <li class="vector-toc-list-item vector-toc-level-3" id="toc-Response">
# <a class="vector-toc-link" href="#Response">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.2.1</span>Response</div>
# </a>
# <ul class="vector-toc-list" id="toc-Response-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Life_expectancy">
# <a class="vector-toc-link" href="#Life_expectancy">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.3</span>Life expectancy</div>
# </a>
# <ul class="vector-toc-list" id="toc-Life_expectancy-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Vaccination_rates">
# <a class="vector-toc-link" href="#Vaccination_rates">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.4</span>Vaccination rates</div>
# </a>
# <ul class="vector-toc-list" id="toc-Vaccination_rates-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-See_also">
# <a class="vector-toc-link" href="#See_also">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>See also</div>
# </a>
# <ul class="vector-toc-list" id="toc-See_also-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-References">
# <a class="vector-toc-link" href="#References">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>References</div>
# </a>
# <ul class="vector-toc-list" id="toc-References-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-External_links">
# <a class="vector-toc-link" href="#External_links">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>External links</div>
# </a>
# <ul class="vector-toc-list" id="toc-External_links-sublist">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="mw-content-container">
# <main class="mw-body" id="content" role="main">
# <header class="mw-body-header vector-page-titlebar">
# <label aria-controls="toc-toggle-list" class="mw-ui-button mw-ui-quiet mw-ui-icon mw-ui-icon-flush-left mw-ui-icon-element mw-ui-icon-wikimedia-listBullet mw-checkbox-hack-button" data-event-name="vector.toc-toggle-list" for="vector-toc-collapsed-checkbox" id="vector-toc-collapsed-button" role="button" tabindex="0" title="Table of Contents">
# 						Toggle the table of contents
# 					</label>
# <div class="vector-menu vector-dropdown vector-menu-dropdown vector-page-titlebar-toc mw-ui-icon-flush-left" id="vector-page-titlebar-toc">
# <input aria-haspopup="true" class="vector-menu-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
# <label class="vector-menu-heading mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-wikimedia-listBullet" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label">
# <span class="vector-menu-heading-label"></span>
# </label>
# <div class="vector-menu-content">
# <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
# </div>
# </div>
# </div>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Healthcare in Europe</span></h1>
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-lang mw-ui-icon-flush-right" id="p-lang-btn">
# <input aria-haspopup="true" aria-label="Go to an article in another language. Available in 1 language" class="vector-menu-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
# <label class="vector-menu-heading mw-ui-button mw-ui-quiet mw-ui-progressive mw-portlet-lang-heading-1" for="p-lang-btn-checkbox" id="p-lang-btn-label">
# <span class="mw-ui-icon mw-ui-icon-wikimedia-language-progressive"></span><span class="vector-menu-heading-label">1 language</span>
# </label>
# <div class="vector-menu-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-uk mw-list-item"><a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%9E%D1%85%D0%BE%D1%80%D0%BE%D0%BD%D0%B0_%D0%B7%D0%B4%D0%BE%D1%80%D0%BE%D0%B2%E2%80%99%D1%8F_%D0%B2_%D0%84%D0%B2%D1%80%D0%BE%D0%BF%D1%96" hreflang="uk" lang="uk" title="Охорона здоров’я в Європі – Ukrainian"><span>Українська</span></a></li></ul>
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q5691262#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </div>
# </div>
# </header>
# <div class="vector-page-toolbar">
# <div class="vector-page-toolbar-container">
# <div id="left-navigation">
# <nav aria-label="Namespaces">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-main"><a accesskey="c" href="/wiki/Healthcare_in_Europe" title="View the content page [c]"><span>Article</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-talk"><a accesskey="t" href="/wiki/Talk:Healthcare_in_Europe" rel="discussion" title="Discuss improvements to the content page [t]"><span>Talk</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-variants emptyPortlet" id="p-variants">
# <input aria-haspopup="true" aria-label="Change language variant" class="vector-menu-checkbox" data-event-name="ui.dropdown-p-variants" id="p-variants-checkbox" role="button" type="checkbox"/>
# <label class="vector-menu-heading" for="p-variants-checkbox" id="p-variants-label">
# <span class="vector-menu-heading-label">English</span>
# </label>
# <div class="vector-menu-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"></ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="vector-collapsible" id="right-navigation">
# <nav aria-label="Views">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views" id="p-views">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected vector-tab-noicon mw-list-item" id="ca-view"><a href="/wiki/Healthcare_in_Europe"><span>Read</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-edit"><a accesskey="e" href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit" title="Edit this page [e]"><span>Edit</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-history"><a accesskey="h" href="/w/index.php?title=Healthcare_in_Europe&amp;action=history" title="Past revisions of this page [h]"><span>View history</span></a></li></ul>
# </div>
# </div>
# </nav>
# <nav aria-label="More options" class="vector-page-tools-landmark">
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items" id="p-cactions" title="More options">
# <input aria-haspopup="true" class="vector-menu-checkbox" data-event-name="ui.dropdown-p-cactions" id="p-cactions-checkbox" role="button" type="checkbox"/>
# <label class="vector-menu-heading" for="p-cactions-checkbox" id="p-cactions-label">
# <span class="vector-menu-heading-label">More</span>
# </label>
# <div class="vector-menu-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected vector-more-collapsible-item mw-list-item" id="ca-more-view"><a href="/wiki/Healthcare_in_Europe"><span>Read</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-edit"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit"><span>Edit</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-history"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=history"><span>View history</span></a></li></ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# </div>
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# </div>
# <div id="contentSub"><div id="mw-content-subtitle"></div></div>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div class="hatnote navigation-not-searchable" role="note">See also: <a class="mw-redirect" href="/wiki/Universal_health_coverage_by_country" title="Universal health coverage by country">Universal health coverage by country</a></div>
# <p class="mw-empty-elt">
# </p>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"><img alt="" class="thumbimage" data-file-height="626" data-file-width="1000" decoding="async" height="138" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/220px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/330px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/440px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" title="Enlarge"></a></div><a href="/wiki/European_Health_Insurance_Card" title="European Health Insurance Card">European Health Insurance Card</a> (French version pictured)</div></div></div>
# <p><b>Healthcare in Europe</b> is provided through a wide range of different systems run at individual <a href="/wiki/Nation" title="Nation">national</a> levels. Most European countries have a system of tightly regulated, competing private health insurance companies, with government subsidies available for citizens who cannot afford coverage.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> Many <a href="/wiki/Europe" title="Europe">European</a> countries (and all <a href="/wiki/European_Union" title="European Union">European Union</a> countries) offer their citizens a <a href="/wiki/European_Health_Insurance_Card" title="European Health Insurance Card">European Health Insurance Card</a> which, on a reciprocal basis, provides insurance for emergency medical treatment insurance when visiting other participating European countries.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </p>
# <meta property="mw:PageProp/toc"/>
# <h2><span class="mw-headline" id="European_health">European health</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=1" title="Edit section: European health">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="wikitable floatright sortable" style="font-size: 90%">
# <caption style="font-size:100%">EU countries with the highest life expectancy (2019)<sup class="reference" id="cite_ref-hdr-life-exp_4-0"><a href="#cite_note-hdr-life-exp-4">[4]</a></sup>
# </caption>
# <tbody><tr>
# <th>World<br/>Rank
# </th>
# <th>EU<br/>Rank
# </th>
# <th>Country
# </th>
# <th colspan="3">Life expectancy<br/>at birth (years)
# </th></tr>
# <tr>
# <td>5.
# </td>
# <td>1.
# </td>
# <td><a href="/wiki/Spain" title="Spain">Spain</a>
# </td>
# <td>83.4
# </td></tr>
# <tr>
# <td>6.
# </td>
# <td>2.
# </td>
# <td><a href="/wiki/Italy" title="Italy">Italy</a>
# </td>
# <td>83.4
# </td></tr>
# <tr>
# <td>11.
# </td>
# <td>3.
# </td>
# <td><a href="/wiki/Sweden" title="Sweden">Sweden</a>
# </td>
# <td>82.7
# </td></tr>
# <tr>
# <td>12.
# </td>
# <td>4.
# </td>
# <td><a href="/wiki/France" title="France">France</a>
# </td>
# <td>82.5
# </td></tr>
# <tr>
# <td>13.
# </td>
# <td>5.
# </td>
# <td><a href="/wiki/Malta" title="Malta">Malta</a>
# </td>
# <td>82.4
# </td></tr>
# <tr>
# <td>16.
# </td>
# <td>6.
# </td>
# <td><a href="/wiki/Ireland" title="Ireland">Ireland</a>
# </td>
# <td>82.1
# </td></tr>
# <tr>
# <td>17.
# </td>
# <td>7.
# </td>
# <td><a href="/wiki/Netherlands" title="Netherlands">Netherlands</a>
# </td>
# <td>82.1
# </td></tr>
# <tr>
# <td>19.
# </td>
# <td>8.
# </td>
# <td><a href="/wiki/Luxembourg" title="Luxembourg">Luxembourg</a>
# </td>
# <td>82.1
# </td></tr>
# <tr>
# <td>20.
# </td>
# <td>9.
# </td>
# <td><a href="/wiki/Greece" title="Greece">Greece</a>
# </td>
# <td>82.1
# </td></tr>
# </tbody></table>
# <p>The <a href="/wiki/World_Health_Organization" title="World Health Organization">World Health Organization</a> has listed 53 countries as comprising the European region. Health outcomes vary greatly by country. Countries in western Europe have had a significant increase in life expectancy since World War II, while most of eastern Europe and the former Soviet countries have experienced a decrease in life expectancy.<sup class="reference" id="cite_ref-lancet1_5-0"><a href="#cite_note-lancet1-5">[5]</a></sup>
# </p><p><a href="/wiki/Tobacco" title="Tobacco">Tobacco</a> use is the largest preventable cause of death in Europe. Many countries have passed legislation in the past few decades restricting tobacco sales and use.<sup class="reference" id="cite_ref-lancet1_5-1"><a href="#cite_note-lancet1-5">[5]</a></sup> According to the European Health Interview Survey (EHIS) conducted between 2013 and 2015, substantial inequalities existed in terms of sex, age and education level concerning the proportion of adults who were daily smokers of cigarettes.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup>
# </p>
# <h3><span class="mw-headline" id="European_Union">European Union</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=2" title="Edit section: European Union">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The <a href="/wiki/European_Union" title="European Union">European Union</a> has no major administrative responsibility in the field of healthcare. The <a href="/wiki/European_Commission" title="European Commission">European Commission's</a> <a class="mw-redirect" href="/wiki/Directorate-General_for_Health_and_Consumers" title="Directorate-General for Health and Consumers">Directorate-General for Health and Consumers</a> however seeks to align national laws on the safety of food and other products, on consumers' rights, and on the protection of people's health, to form new EU wide laws and thus strengthen its internal markets.<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (January 2021)">citation needed</span></a></i>]</sup>
# </p><p>Both the <a href="/wiki/World_Health_Organization" title="World Health Organization">World Health Organization</a> Regional Office for Europe (<a href="/wiki/List_of_WHO_regions#European_Region_(EURO)" title="List of WHO regions">WHO/Europe</a>) and the <a href="/wiki/European_Centre_for_Disease_Prevention_and_Control" title="European Centre for Disease Prevention and Control">European Centre for Disease Prevention and Control</a> are involved in public health development in Europe.<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup>
# </p>
# <h3><span class="mw-headline" id="COVID-19_pandemic">COVID-19 pandemic</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=3" title="Edit section: COVID-19 pandemic">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The <a href="/wiki/European_Union" title="European Union">European Union</a> countries were impacted by the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>. The governments of the various countries adopted healthcare standards aimed at the number of <a href="/wiki/Infection" title="Infection">infected</a> and people who are deceased. A widespread vaccination campaign helped to lower the COVID-19 <a href="/wiki/Mortality_rate" title="Mortality rate">mortality rate</a>. In addition to the <a class="mw-redirect" href="/wiki/COVID-19_vaccines" title="COVID-19 vaccines">COVID-19 vaccines</a>, the mortality rates were determined by the number of <a class="mw-redirect" href="/wiki/Physicians" title="Physicians">physicians</a>, the number of available <a href="/wiki/Intensive_care_unit" title="Intensive care unit">Intensive care unit</a> (ICU) beds and safety policies carried out by governments. Mortality rates varied in Europe depending on whether the countries have a higher or lower rate of the adult population over 65 years of age. Studies show that having an adequate number of <a class="mw-redirect" href="/wiki/Health_professionals" title="Health professionals">health professionals</a> is one of the most important variables in reducing the number of deaths.<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
# </p>
# <h4><span class="mw-headline" id="Response">Response</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=4" title="Edit section: Response">edit</a><span class="mw-editsection-bracket">]</span></span></h4>
# <p>The emergence of the <a href="/wiki/Coronavirus" title="Coronavirus">Coronavirus</a> has upended life as we know it in various <a href="/wiki/European_Union" title="European Union">European Union</a> countries. In responding to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, <a href="/wiki/Public_health" title="Public health">public health</a> infrastructures and resources, governmental, and cultural values all play a key role in stopping the threat. Finding an approach that balances effectiveness, efficiency, and successful response to the pandemic is the key to ending the crisis.
# </p><p>European Union countries like <a href="/wiki/Greece" title="Greece">Greece</a> and <a href="/wiki/Sweden" title="Sweden">Sweden</a> have similar populations and sizes. They have a difficult cultural and political stance. The government response of various European countries to the pandemic was to stay home and slow down the spread of the virus. It was proactive in closing businesses and stores early on and even before the first COVID-19 death. The governmental response including the banning of all <a href="/wiki/International_non-essential_travel" title="International non-essential travel">international non-essential travel</a> and <a href="/wiki/COVID-19_lockdowns" title="COVID-19 lockdowns">COVID-19 lockdowns</a> helped to keep the death toll to a minimum.<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </p><p>In comparison, the government response to <a class="mw-redirect" href="/wiki/COVID-19_in_Sweden" title="COVID-19 in Sweden">COVID-19 in Sweden</a> was much less stringent than in <a href="/wiki/COVID-19_pandemic_in_Greece" title="COVID-19 pandemic in Greece">Greece</a>. The government of Sweden focused on guidelines that encourage all citizens to take personal responsibility in containing the virus. The <a href="/wiki/Public_Health_Agency_of_Sweden" title="Public Health Agency of Sweden">Public Health Agency of Sweden</a> proposed a ban on gatherings over 500 people, including <a href="/wiki/Social_distancing" title="Social distancing">social distancing</a>. The key concept proposed was solidarity through individual responsibility with all Swedish citizens obeying the guidelines.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </p><p><a href="/wiki/Triage" title="Triage">Triaging</a> issues that determined medical priority to increase <a class="mw-redirect" href="/wiki/Survival_rates" title="Survival rates">survival rates</a> from COVID-19 contrasted between Sweden and Greece. The Europeans focused strictly on medical protocols and technical expertise from the medical field. This caused a fundamental collapse of the healthcare system, needless deaths, and a misinformed and distrusting public that demanded more <a href="/wiki/Accountability" title="Accountability">accountability</a> from the <a href="/wiki/Member_state_of_the_European_Union" title="Member state of the European Union">European Union members</a>, the government, and <a href="/wiki/Health_professional" title="Health professional">health professionals</a>. With a similar population of 10 million people and other issues aside. As of 10 December 2021, there have been 18,982 deaths in Greece and 15,152 deaths in Sweden.<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Life_expectancy">Life expectancy</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=5" title="Edit section: Life expectancy">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>There is a big gap between genders in <a href="/wiki/Life_expectancy" title="Life expectancy">life expectancy</a> due to income groups. Studies show that the highest income group tends to live longer. For example, <a href="/wiki/Eastern_Europe" title="Eastern Europe">Eastern Europe</a> is a low-income region, with a lower life expectancy due to <a class="mw-redirect" href="/wiki/Biological_factors" title="Biological factors">biological factors</a> including <a href="/wiki/Genetics" title="Genetics">genetics</a>, <a href="/wiki/Nutrition" title="Nutrition">nutrition</a>, and even hormonal issues. However, other factors are non-biological such as <a href="/wiki/Smoking" title="Smoking">smoking</a> and <a href="/wiki/Drinking" title="Drinking">drinking</a> that tend to be part of the decrease in life expectancy for men. These unhealthy lifestyles create life-threatening diseases such as <a href="/wiki/Lung_cancer" title="Lung cancer">lung cancer</a> and cardiovascular complications. The consumption of alcohol in Europe by men is usually more common between the ages of 20–34 years in men and would increase the life expectancy if consumption is lowered. Another non-biological factor that cooperates with the decrease in life expectancy in <a href="/wiki/Eastern_Europe" title="Eastern Europe">Eastern Europe</a> would be unhealthy stress that affects <a class="mw-redirect" href="/wiki/Cardiovascular_health" title="Cardiovascular health">cardiovascular health</a>.<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </p><p>Life expectancy has risen from <a class="mw-redirect" href="/wiki/Birth_rates" title="Birth rates">birth rates</a> due to significant factors such as the decrease in children's mortality rates, increase in the standard of living, better education, and advances in <a class="mw-redirect" href="/wiki/Healthcare" title="Healthcare">healthcare</a> and <a href="/wiki/Medicine" title="Medicine">medicine</a>. Since the 1960s studies and statistics have shown a rise in life expectancy by a pair of numbers per decade. However, from 2019 to 2020 a slight increase in life expectancy occurred by about 0.2 yrs. Nonetheless, in 2020 a drastic decrease in life expectancy occurred by about - 1.75. This occurred only in some states of Europe because of the COVID-19 pandemic.  According to a new study published by the Smithsonian Magazine by the author Ridhi Kashyap, an associate professor of social demography at the <a href="/wiki/University_of_Oxford" title="University of Oxford">University of Oxford</a>.<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (September 2022)">citation needed</span></a></i>]</sup>
# </p><p>The decrease in life expectancy has been a dramatic one, which is known to be the biggest decrease in life expectancy compared to <a href="/wiki/World_War_II" title="World War II">World War II</a>. The explanation given is because due to the poor life expectancy already occurring in the European Union, <a href="/wiki/COVID-19" title="COVID-19">COVID-19</a> made it worse, decreasing life expectancy and causing more deaths.<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Vaccination_rates">Vaccination rates</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=6" title="Edit section: Vaccination rates">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Vaccines are a powerful tool being used nationwide against COVID-19. At the beginning of the <a href="/wiki/Pandemic" title="Pandemic">pandemic</a>, the <a href="/wiki/Europe" title="Europe">European</a> population aimed to help individuals that were at most risk. This may include older adults over the age of 65 which are more likely to have other health issues. Minorities who do not have complete access to assistance and help from the <a href="/wiki/Government" title="Government">government</a>. Individuals with disabilities are more likely to be affected because of their underlying <a class="mw-redirect" href="/wiki/Medical_conditions" title="Medical conditions">medical conditions</a>. <a class="mw-redirect" href="/wiki/Minorities" title="Minorities">Minorities</a> who do not have access to the highest level of <a class="mw-redirect" href="/wiki/Medical" title="Medical">medical</a> help.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup>
# ...
# <li class="mw-empty-elt"></li>
# <li><a href="/wiki/List_of_hospitals_in_Italy" title="List of hospitals in Italy">Italy</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Kazakhstan" title="List of hospitals in Kazakhstan">Kazakhstan</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Latvia" title="List of hospitals in Latvia">Latvia</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Liechtenstein" title="List of hospitals in Liechtenstein">Liechtenstein</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Lithuania" title="List of hospitals in Lithuania">Lithuania</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Luxembourg" title="List of hospitals in Luxembourg">Luxembourg</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Malta" title="List of hospitals in Malta">Malta</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Moldova" title="List of hospitals in Moldova">Moldova</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Monaco" title="List of hospitals in Monaco">Monaco</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Montenegro" title="List of hospitals in Montenegro">Montenegro</a></li>
# <li><a href="/wiki/List_of_hospitals_in_the_Netherlands" title="List of hospitals in the Netherlands">Netherlands</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_North_Macedonia" title="List of hospitals in North Macedonia">North Macedonia</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Norway" title="List of hospitals in Norway">Norway</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Poland" title="List of hospitals in Poland">Poland</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Portugal" title="List of hospitals in Portugal">Portugal</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Romania" title="List of hospitals in Romania">Romania</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Russia" title="List of hospitals in Russia">Russia</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_San_Marino" title="List of hospitals in San Marino">San Marino</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Serbia" title="List of hospitals in Serbia">Serbia</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Slovakia" title="List of hospitals in Slovakia">Slovakia</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Slovenia" title="List of hospitals in Slovenia">Slovenia</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Spain" title="List of hospitals in Spain">Spain</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Sweden" title="List of hospitals in Sweden">Sweden</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Switzerland" title="List of hospitals in Switzerland">Switzerland</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Turkey" title="List of hospitals in Turkey">Turkey</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Ukraine" title="List of hospitals in Ukraine">Ukraine</a></li>
# <li><a href="/wiki/List_of_hospitals_in_the_United_Kingdom" title="List of hospitals in the United Kingdom">United Kingdom</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Vatican_City" title="List of hospitals in Vatican City">Vatican City</a></li></ul>
# </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%">States with limited<br/>recognition</th><td class="navbox-list-with-group navbox-list navbox-even hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">
# <ul><li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Abkhazia" title="List of hospitals in Abkhazia">Abkhazia</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_the_Republic_of_Artsakh" title="List of hospitals in the Republic of Artsakh">Artsakh</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Kosovo" title="List of hospitals in Kosovo">Kosovo</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Northern_Cyprus" title="List of hospitals in Northern Cyprus">Northern Cyprus</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_South_Ossetia" title="List of hospitals in South Ossetia">South Ossetia</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Transnistria" title="List of hospitals in Transnistria">Transnistria</a></li></ul>
# </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%">Dependencies and<br/>other entities</th><td class="navbox-list-with-group navbox-list navbox-odd hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">
# <ul><li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_%C3%85land" title="List of hospitals in Åland">Åland</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_the_Faroe_Islands" title="List of hospitals in the Faroe Islands">Faroe Islands</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Gibraltar" title="List of hospitals in Gibraltar">Gibraltar</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Guernsey" title="List of hospitals in Guernsey">Guernsey</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_the_Isle_of_Man" title="List of hospitals in the Isle of Man">Isle of Man</a></li>
# <li><a href="/wiki/List_of_hospitals_in_Jersey" title="List of hospitals in Jersey">Jersey</a></li>
# <li><a class="mw-redirect" href="/wiki/List_of_hospitals_in_Svalbard" title="List of hospitals in Svalbard">Svalbard</a></li></ul>
# </div></td></tr></tbody></table></div>
# <div class="navbox-styles"><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><link href="mw-data:TemplateStyles:r1061467846" rel="mw-deduplicated-inline-style"/></div><div aria-label="Navbox" class="navbox authority-control" role="navigation" style="padding:3px"><table class="nowraplinks hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a>: National libraries <a href="https://www.wikidata.org/wiki/Q5691262#identifiers" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" class="noprint" data-file-height="20" data-file-width="20" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" style="vertical-align: text-top" width="10"/></a></th><td class="navbox-list-with-group navbox-list navbox-odd" style="width:100%;padding:0"><div style="padding:0 0.25em">
# <ul><li><span class="uid"><a class="external text" href="https://id.loc.gov/authorities/subjects/sh2010101166" rel="nofollow">United States</a></span></li></ul>
# </div></td></tr></tbody></table></div>
# <!--
# NewPP limit report
# Parsed by mw2412
# Cached time: 20230118030825
# Cache expiry: 1814400
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 0.629 seconds
# Real time usage: 0.750 seconds
# Preprocessor visited node count: 33691/1000000
# Post‐expand include size: 129501/2097152 bytes
# Template argument size: 18989/2097152 bytes
# Highest expansion depth: 15/100
# Expensive parser function count: 17/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 75437/5000000 bytes
# Lua time usage: 0.267/10.000 seconds
# Lua memory usage: 7477159/52428800 bytes
# Number of Wikibase entities loaded: 1/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  656.100      1 -total
#  56.14%  368.334      3 Template:Navbox
#  39.83%  261.348    147 Template:Iso2country
#  32.10%  210.619      2 Template:Europe_in_topic
#  25.83%  169.485      1 Template:Health_care_in_Europe
#  25.38%  166.505      1 Template:Europe_topic
#  20.01%  131.287      1 Template:Reflist
#  12.87%   84.459      9 Template:Cite_web
#  11.79%   77.335    147 Template:Iso2country/data
#   5.73%   37.578      2 Template:Fix
# -->
# <!-- Saved in parser cache with key enwiki:pcache:idhash:15973120-0!canonical and timestamp 20230118030825 and revision id 1131475728.
#  -->
# </div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img alt="" height="1" src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/></noscript>
# <div class="printfooter" data-nosnippet="">Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728">https://en.wikipedia.org/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728</a>"</div></div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Health_in_Europe" title="Category:Health in Europe">Health in Europe</a></li></ul></div><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Hidden categories: <ul><li><a href="/wiki/Category:CS1_maint:_url-status" title="Category:CS1 maint: url-status">CS1 maint: url-status</a></li><li><a href="/wiki/Category:Use_dmy_dates_from_December_2021" title="Category:Use dmy dates from December 2021">Use dmy dates from December 2021</a></li><li><a href="/wiki/Category:All_articles_with_unsourced_statements" title="Category:All articles with unsourced statements">All articles with unsourced statements</a></li><li><a href="/wiki/Category:Articles_with_unsourced_statements_from_January_2021" title="Category:Articles with unsourced statements from January 2021">Articles with unsourced statements from January 2021</a></li><li><a href="/wiki/Category:Articles_with_unsourced_statements_from_September_2022" title="Category:Articles with unsourced statements from September 2022">Articles with unsourced statements from September 2022</a></li><li><a href="/wiki/Category:Articles_with_LCCN_identifiers" title="Category:Articles with LCCN identifiers">Articles with LCCN identifiers</a></li></ul></div></div>
# </div>
# </main>
# </div>
# <div class="mw-footer-container">
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 4 January 2023, at 09:32<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License 3.0</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Privacy_policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Healthcare_in_Europe&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# </div>
# </div>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.629","walltime":"0.750","ppvisitednodes":{"value":33691,"limit":1000000},"postexpandincludesize":{"value":129501,"limit":2097152},"templateargumentsize":{"value":18989,"limit":2097152},"expansiondepth":{"value":15,"limit":100},"expensivefunctioncount":{"value":17,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":75437,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  656.100      1 -total"," 56.14%  368.334      3 Template:Navbox"," 39.83%  261.348    147 Template:Iso2country"," 32.10%  210.619      2 Template:Europe_in_topic"," 25.83%  169.485      1 Template:Health_care_in_Europe"," 25.38%  166.505      1 Template:Europe_topic"," 20.01%  131.287      1 Template:Reflist"," 12.87%   84.459      9 Template:Cite_web"," 11.79%   77.335    147 Template:Iso2country/data","  5.73%   37.578      2 Template:Fix"]},"scribunto":{"limitreport-timeusage":{"value":"0.267","limit":"10.000"},"limitreport-memusage":{"value":7477159,"limit":52428800}},"cachereport":{"origin":"mw2412","timestamp":"20230118030825","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Healthcare in Europe","url":"https:\/\/en.wikipedia.org\/wiki\/Healthcare_in_Europe","sameAs":"http:\/\/www.wikidata.org\/entity\/Q5691262","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q5691262","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2008-02-26T22:37:01Z","dateModified":"2023-01-04T09:32:14Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/2\/24\/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"}</script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Healthcare in Europe","url":"https:\/\/en.wikipedia.org\/wiki\/Healthcare_in_Europe","sameAs":"http:\/\/www.wikidata.org\/entity\/Q5691262","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q5691262","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2008-02-26T22:37:01Z","dateModified":"2023-01-04T09:32:14Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/2\/24\/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":95,"wgHostname":"mw2387"});});</script>
# </body>
# </html>

# %%
webpage=urllib2.urlopen(url)
htmlpage=webpage.readlines()
lst=[]
for line in htmlpage:
    line =str(line).rstrip()
    if re.search('table class',line):
        lst.append(line)

# %%
len(lst)
# Out:
# 5

# %%
webpage

# %%
htmlpage
# Out:
# [b'<!DOCTYPE html>\n',
#  b'<html class="client-nojs" lang="en" dir="ltr">\n',
#  b'<head>\n',
#  b'<meta charset="UTF-8"/>\n',
#  b'<title>Healthcare in Europe - Wikipedia</title>\n',
#  b'<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"ed6a519b-7f3c-46fb-a177-4ed701874d04","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Healthcare_in_Europe","wgTitle":"Healthcare in Europe","wgCurRevisionId":1131475728,"wgRevisionId":1131475728,"wgArticleId":15973120,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: url-status","Use dmy dates from December 2021","All articles with unsourced statements","Articles with unsourced statements from January 2021","Articles with unsourced statements from September 2022","Articles with LCCN identifiers","Health in Europe"],\n',
#  b'"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Healthcare_in_Europe","wgRelevantArticleId":15973120,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q5691262","GEHomepageSuggestedEditsEnableTopics":true,\n',
#  b'"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","skins.vector.es6","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging",\n',
#  b'"ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.cx.uls.quick.actions","ext.growthExperiments.SuggestedEditSession"];</script>\n',
#  b'<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n',
#  b'<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.ui.button%2Cicon%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022"/>\n',
#  b'<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>\n',
#  b'<meta name="ResourceLoaderDynamicStyles" content=""/>\n',
#  b'<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022"/>\n',
#  b'<meta name="generator" content="MediaWiki 1.40.0-wmf.19"/>\n',
#  b'<meta name="referrer" content="origin"/>\n',
#  b'<meta name="referrer" content="origin-when-crossorigin"/>\n',
#  b'<meta name="referrer" content="origin-when-cross-origin"/>\n',
#  b'<meta name="robots" content="max-image-preview:standard"/>\n',
#  b'<meta name="format-detection" content="telephone=no"/>\n',
#  b'<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"/>\n',
#  b'<meta property="og:image:width" content="1200"/>\n',
#  b'<meta property="og:image:height" content="751"/>\n',
#  b'<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/800px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"/>\n',
#  b'<meta property="og:image:width" content="800"/>\n',
#  b'<meta property="og:image:height" content="501"/>\n',
#  b'<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/640px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg"/>\n',
#  b'<meta property="og:image:width" content="640"/>\n',
#  b'<meta property="og:image:height" content="401"/>\n',
#  b'<meta name="viewport" content="width=1000"/>\n',
#  b'<meta property="og:title" content="Healthcare in Europe - Wikipedia"/>\n',
#  b'<meta property="og:type" content="website"/>\n',
#  b'<link rel="preconnect" href="//upload.wikimedia.org"/>\n',
#  b'<link rel="alternate" media="only screen and (max-width: 720px)" href="//en.m.wikipedia.org/wiki/Healthcare_in_Europe"/>\n',
#  b'<link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit"/>\n',
#  b'<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>\n',
#  b'<link rel="icon" href="/static/favicon/wikipedia.ico"/>\n',
#  b'<link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>\n',
#  b'<link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>\n',
#  b'<link rel="license" href="https://creativecommons.org/licenses/by-sa/3.0/"/>\n',
#  b'<link rel="canonical" href="https://en.wikipedia.org/wiki/Healthcare_in_Europe"/>\n',
#  b'<link rel="dns-prefetch" href="//meta.wikimedia.org" />\n',
#  b'<link rel="dns-prefetch" href="//login.wikimedia.org"/>\n',
#  b'</head>\n',
#  b'<body class="skin-vector skin-vector-search-vue vector-toc-pinned mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Healthcare_in_Europe rootpage-Healthcare_in_Europe skin-vector-2022 action-view vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-sticky-header-edit-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled"><div class="mw-page-container">\n',
#  b'\t<a class="mw-jump-link" href="#bodyContent">Jump to content</a>\n',
#  b'\t<div class="mw-page-container-inner">\n',
#  b'\t\t<input\n',
#  b'\t\t\ttype="checkbox"\n',
#  b'\t\t\tid="mw-sidebar-checkbox"\n',
#  b'\t\t\tclass="mw-checkbox-hack-checkbox"\n',
#  b'\t\t\t>\n',
#  b'\t\t<header class="mw-header mw-ui-icon-flush-left mw-ui-icon-flush-right">\n',
#  b'\t\t\t<div class="vector-header-start">\n',
#  b'\t\t\t\t\t<label\n',
#  b'\t\t\t\tid="mw-sidebar-button"\n',
#  b'\t\t\t\tclass="mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-flush-right"\n',
#  b'\t\t\t\tfor="mw-sidebar-checkbox"\n',
#  b'\t\t\t\trole="button"\n',
#  b'\t\t\t\taria-controls="mw-panel"\n',
#  b'\t\t\t\tdata-event-name="ui.sidebar"\n',
#  b'\t\t\t\ttabindex="0"\n',
#  b'\t\t\t\ttitle="Main menu">\n',
#  b'\t\t\t\t<span>Toggle sidebar</span>\n',
#  b'\t\t\t</label>\n',
#  b'\t\t\n',
#  b'<a href="/wiki/Main_Page" class="mw-logo">\n',
#  b'\t<img class="mw-logo-icon" src="/static/images/icons/wikipedia.png" alt=""\n',
#  b'\t\taria-hidden="true" height="50" width="50">\n',
#  b'\t<span class="mw-logo-container">\n',
#  b'\t\t<img class="mw-logo-wordmark" alt="Wikipedia"\n',
#  b'\t\t\tsrc="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;">\n',
#  b'\t\t<img class="mw-logo-tagline"\n',
#  b'\t\t\talt="The Free Encyclopedia"\n',
#  b'\t\t\tsrc="/static/images/mobile/copyright/wikipedia-tagline-en.svg" width="117" height="13" style="width: 7.3125em; height: 0.8125em;">\n',
#  b'\t</span>\n',
#  b'</a>\n',
#  b'\n',
#  b'\t\t\t</div>\n',
#  b'\t\t\t<div class="vector-header-end">\n',
#  b'\t\t\t\t\n',
#  b'<div id="p-search" role="search" class="vector-search-box-vue  vector-search-box-collapses  vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box">\n',
#  b'\t<a href="/wiki/Special:Search"\n',
#  b'\t\n',
#  b'\t\t\n',
#  b'\t\t\n',
#  b'\t\t\n',
#  b'\t\ttitle="Search Wikipedia [f]"\n',
#  b'\t\taccesskey="f"\n',
#  b'\t\tclass="mw-ui-button mw-ui-quiet mw-ui-icon mw-ui-icon-element mw-ui-icon-wikimedia-search search-toggle">\n',
#  b'\t\t<span>Search</span>\n',
#  b'\t</a>\n',
#  b'\t\n',
#  b'\t<div>\n',
#  b'\t\t<form action="/w/index.php" id="searchform"\n',
#  b'\t\t\tclass="vector-search-box-form">\n',
#  b'\t\t\t<div id="simpleSearch"\n',
#  b'\t\t\t\tclass="vector-search-box-inner"\n',
#  b'\t\t\t\t data-search-loc="header-moved">\n',
#  b'\t\t\t\t<input class="vector-search-box-input"\n',
#  b'\t\t\t\t\t type="search" name="search" placeholder="Search Wikipedia" aria-label="Search Wikipedia" autocapitalize="sentences" title="Search Wikipedia [f]" accesskey="f" id="searchInput"\n',
#  b'\t\t\t\t>\n',
#  b'\t\t\t\t<input type="hidden" name="title" value="Special:Search">\n',
#  b'\t\t\t\t<input id="mw-searchButton"\n',
#  b'\t\t\t\t\t class="searchButton mw-fallbackSearchButton" type="submit" name="fulltext" title="Search Wikipedia for this text" value="Search">\n',
#  b'\t\t\t\t<input id="searchButton"\n',
#  b'\t\t\t\t\t class="searchButton" type="submit" name="go" title="Go to a page with this exact name if it exists" value="Go">\n',
#  b'\t\t\t</div>\n',
#  b'\t\t</form>\n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t\t\t<nav class="vector-user-links" aria-label="Personal tools" role="navigation" >\n',
#  b'\t\n',
#  b'<div id="p-vector-user-menu-overflow" class="vector-menu mw-portlet mw-portlet-vector-user-menu-overflow"  >\n',
#  b'\t<div class="vector-menu-heading">\n',
#  b'\t\t\n',
#  b'\t</div>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="pt-createaccount-2" class="user-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Healthcare+in+Europe" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\n',
#  b'\t<div id="p-personal" class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-personal vector-user-menu vector-user-menu-logged-out"  title="More options" >\n',
#  b'\t\t<input type="checkbox"\n',
#  b'\t\t\tid="p-personal-checkbox"\n',
#  b'\t\t\trole="button"\n',
#  b'\t\t\taria-haspopup="true"\n',
#  b'\t\t\tdata-event-name="ui.dropdown-p-personal"\n',
#  b'\t\t\tclass="vector-menu-checkbox "\n',
#  b'\t\t\t\n',
#  b'\t\t\t\n',
#  b'\t\t/>\n',
#  b'\t\t<label\n',
#  b'\t\t\tid="p-personal-label"\n',
#  b'\t\t\tfor="p-personal-checkbox"\n',
#  b'\t\t\tclass="vector-menu-heading mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-wikimedia-ellipsis"\n',
#  b'\t\t\t\n',
#  b'\t\t>\n',
#  b'\t\t\t<span class="vector-menu-heading-label">Foo</span>\n',
#  b'\t\t</label>\n',
#  b'\t\t<div class="vector-menu-content">\n',
#  b'\t\n',
#  b'\t\t<div class="vector-menu-content">\n',
#  b'    \n',
#  b'    <ul class="vector-menu-content-list"><li class="vector-user-menu-create-account user-links-collapsible-item" ><a data-mw="interface"\n',
#  b'    href="/w/index.php?title=Special:CreateAccount&amp;returnto=Healthcare+in+Europe"\n',
#  b'    ><span class="mw-ui-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span><span>Create account</span></a>\n',
#  b'</li><li class="vector-user-menu-login" ><a data-mw="interface"\n',
#  b'    href="/w/index.php?title=Special:UserLogin&amp;returnto=Healthcare+in+Europe"\n',
#  b'     title="[o]" accesskey="o"><span class="mw-ui-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span><span>Log in</span></a>\n',
#  b'</li></ul>\n',
#  b'    \n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t<div class="vector-user-menu-anon-editor">\n',
#  b'\t\t\t<p>\n',
#  b'\t\t\t\tPages for logged out editors <a data-mw="interface"\n',
#  b'    href="/wiki/Help:Introduction"\n',
#  b'     aria-label="Learn more about editing"><span>learn more</span></a>\n',
#  b'\n',
#  b'\t\t\t</p>\n',
#  b'\t\t</div>\n',
#  b'\t\t\t\t<div class="vector-menu-content">\n',
#  b'    \n',
#  b'    <ul class="vector-menu-content-list"><li id="pt-anontalk" class="mw-list-item"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n"><span>Talk</span></a></li><li id="pt-anoncontribs" class="mw-list-item"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y"><span>Contributions</span></a></li></ul>\n',
#  b'    \n',
#  b'</div>\n',
#  b'\n',
#  b'\t\n',
#  b'\t\t</div>\n',
#  b'\t</div></nav>\n',
#  b'\n',
#  b'\t\t\t</div>\n',
#  b'\t\t</header>\n',
#  b'\t\t<div class="vector-main-menu-container ">\n',
#  b'\t\t\t<div id="mw-navigation">\n',
#  b'\t\t\t\t<nav id="mw-panel" class="vector-main-menu-landmark" aria-label="Site" role="navigation">\n',
#  b'\t\t\t\t\t\t\n',
#  b'<div id="vector-main-menu" class="vector-main-menu vector-pinnable-element">\n',
#  b'\t\n',
#  b'    \n',
#  b'<div id="p-navigation" class="vector-main-menu-group vector-menu mw-portlet mw-portlet-navigation"  >\n',
#  b'\t<div\n',
#  b'\t\tid="p-navigation-label"\n',
#  b'\t\tclass="vector-menu-heading "\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">Navigation</span>\n',
#  b'\t</div>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="n-mainpage-description" class="mw-list-item"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z"><span>Main page</span></a></li><li id="n-contents" class="mw-list-item"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li id="n-currentevents" class="mw-list-item"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li id="n-randompage" class="mw-list-item"><a href="/wiki/Special:Random" title="Visit a randomly selected article [x]" accesskey="x"><span>Random article</span></a></li><li id="n-aboutsite" class="mw-list-item"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li id="n-contactpage" class="mw-list-item"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li id="n-sitesupport" class="mw-list-item"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'    \n',
#  b'    \n',
#  b'<div id="p-interaction" class="vector-main-menu-group vector-menu mw-portlet mw-portlet-interaction"  >\n',
#  b'\t<div\n',
#  b'\t\tid="p-interaction-label"\n',
#  b'\t\tclass="vector-menu-heading "\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">Contribute</span>\n',
#  b'\t</div>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="n-help" class="mw-list-item"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li id="n-introduction" class="mw-list-item"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li id="n-portal" class="mw-list-item"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li id="n-recentchanges" class="mw-list-item"><a href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]" accesskey="r"><span>Recent changes</span></a></li><li id="n-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'<div id="p-tb" class="vector-main-menu-group vector-menu mw-portlet mw-portlet-tb"  >\n',
#  b'\t<div\n',
#  b'\t\tid="p-tb-label"\n',
#  b'\t\tclass="vector-menu-heading "\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">Tools</span>\n',
#  b'\t</div>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="t-whatlinkshere" class="mw-list-item"><a href="/wiki/Special:WhatLinksHere/Healthcare_in_Europe" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j"><span>What links here</span></a></li><li id="t-recentchangeslinked" class="mw-list-item"><a href="/wiki/Special:RecentChangesLinked/Healthcare_in_Europe" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k"><span>Related changes</span></a></li><li id="t-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u"><span>Upload file</span></a></li><li id="t-specialpages" class="mw-list-item"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q"><span>Special pages</span></a></li><li id="t-permalink" class="mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li id="t-info" class="mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li id="t-cite" class="mw-list-item"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Healthcare_in_Europe&amp;id=1131475728&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li id="t-wikibase" class="mw-list-item"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q5691262" title="Structured data on this page hosted by Wikidata [g]" accesskey="g"><span>Wikidata item</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'<div id="p-coll-print_export" class="vector-main-menu-group vector-menu mw-portlet mw-portlet-coll-print_export"  >\n',
#  b'\t<div\n',
#  b'\t\tid="p-coll-print_export-label"\n',
#  b'\t\tclass="vector-menu-heading "\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">Print/export</span>\n',
#  b'\t</div>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="coll-download-as-rl" class="mw-list-item"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Healthcare_in_Europe&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li id="t-print" class="mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;printable=yes" title="Printable version of this page [p]" accesskey="p"><span>Printable version</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'    \n',
#  b'<div class="vector-main-menu-action vector-main-menu-action-lang-alert">\n',
#  b'\t<div class="vector-main-menu-action-item">\n',
#  b'\t\t<div class="vector-main-menu-action-heading vector-menu-heading">Languages</div>\n',
#  b'\t\t<div class="vector-main-menu-action-content vector-menu-content">\n',
#  b'\t\t\t<div class="mw-message-box-notice vector-language-sidebar-alert mw-message-box">On this Wikipedia the language links are at the top of the page across from the article title. <a href="#p-lang-btn">Go to top</a>.</div>\n',
#  b'\t\t</div>\n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t\t\t</nav>\n',
#  b'\t\t\t</div>\n',
#  b'\t\t</div>\n',
#  b'\t\t<div class="vector-sitenotice-container">\n',
#  b'\t\t\t<div id="siteNotice"><!-- CentralNotice --></div>\n',
#  b'\t\t</div>\n',
#  b'\t\t<input type="checkbox" id="vector-toc-collapsed-checkbox" class="mw-checkbox-hack-checkbox">\n',
#  b'\t\t<nav id="mw-panel-toc" role="navigation" aria-label="Contents" data-event-name="ui.sidebar-toc" class="mw-table-of-contents-container">\n',
#  b'\t\t\t<div id="vector-toc-pinned-container" class="vector-pinned-container">\n',
#  b'\t\t<div id="vector-toc" class="vector-toc vector-pinnable-element">\n',
#  b'\t<div\n',
#  b'\tclass="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned"\n',
#  b'\tdata-name="vector-toc"\n',
#  b'\t\n',
#  b'\t\n',
#  b'\t\n',
#  b'\t\n',
#  b'>\n',
#  b'\t<h2 class="vector-pinnable-header-label">Contents</h2>\n',
#  b'\t<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>\n',
#  b'\t<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>\n',
#  b'</div>\n',
#  b'\n',
#  b'\n',
#  b'\t<ul class="vector-toc-contents" id="mw-panel-toc-list">\n',
#  b'\t\t<li id="toc-mw-content-text"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-1">\n',
#  b'\t\t\t<a href="#" class="vector-toc-link">\n',
#  b'\t\t\t\t<div class="vector-toc-text">(Top)</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t</li>\n',
#  b'\t\t<li id="toc-European_health"\n',
#  b'\t\tclass="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n',
#  b'\t\t<a class="vector-toc-link" href="#European_health">\n',
#  b'\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t<span class="vector-toc-numb">1</span>European health</div>\n',
#  b'\t\t</a>\n',
#  b'\t\t\n',
#  b'\t\t\t<button aria-controls="toc-European_health-sublist" class="mw-ui-icon mw-ui-icon-wikimedia-expand mw-ui-icon-small vector-toc-toggle">\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t</button>\n',
#  b'\t\t\n',
#  b'\t\t<ul id="toc-European_health-sublist" class="vector-toc-list">\n',
#  b'\t\t\t<li id="toc-European_Union"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-2">\n',
#  b'\t\t\t<a class="vector-toc-link" href="#European_Union">\n',
#  b'\t\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t\t<span class="vector-toc-numb">1.1</span>European Union</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t\t\n',
#  b'\t\t\t<ul id="toc-European_Union-sublist" class="vector-toc-list">\n',
#  b'\t\t\t</ul>\n',
#  b'\t\t</li>\n',
#  b'\t\t<li id="toc-COVID-19_pandemic"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-2">\n',
#  b'\t\t\t<a class="vector-toc-link" href="#COVID-19_pandemic">\n',
#  b'\t\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t\t<span class="vector-toc-numb">1.2</span>COVID-19 pandemic</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t\t\n',
#  b'\t\t\t<ul id="toc-COVID-19_pandemic-sublist" class="vector-toc-list">\n',
#  b'\t\t\t\t<li id="toc-Response"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-3">\n',
#  b'\t\t\t<a class="vector-toc-link" href="#Response">\n',
#  b'\t\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t\t<span class="vector-toc-numb">1.2.1</span>Response</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t\t\n',
#  b'\t\t\t<ul id="toc-Response-sublist" class="vector-toc-list">\n',
#  b'\t\t\t</ul>\n',
#  b'\t\t</li>\n',
#  b'\t</ul>\n',
#  b'\t\t</li>\n',
#  b'\t\t<li id="toc-Life_expectancy"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-2">\n',
#  b'\t\t\t<a class="vector-toc-link" href="#Life_expectancy">\n',
#  b'\t\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t\t<span class="vector-toc-numb">1.3</span>Life expectancy</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t\t\n',
#  b'\t\t\t<ul id="toc-Life_expectancy-sublist" class="vector-toc-list">\n',
#  b'\t\t\t</ul>\n',
#  b'\t\t</li>\n',
#  b'\t\t<li id="toc-Vaccination_rates"\n',
#  b'\t\t\tclass="vector-toc-list-item vector-toc-level-2">\n',
#  b'\t\t\t<a class="vector-toc-link" href="#Vaccination_rates">\n',
#  b'\t\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t\t<span class="vector-toc-numb">1.4</span>Vaccination rates</div>\n',
#  b'\t\t\t</a>\n',
#  b'\t\t\t\n',
#  b'\t\t\t<ul id="toc-Vaccination_rates-sublist" class="vector-toc-list">\n',
#  b'\t\t\t</ul>\n',
#  b'\t\t</li>\n',
#  b'\t</ul>\n',
#  b'\t</li>\n',
#  b'\t<li id="toc-See_also"\n',
#  b'\t\tclass="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n',
#  b'\t\t<a class="vector-toc-link" href="#See_also">\n',
#  b'\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t<span class="vector-toc-numb">2</span>See also</div>\n',
#  b'\t\t</a>\n',
#  b'\t\t\n',
#  b'\t\t<ul id="toc-See_also-sublist" class="vector-toc-list">\n',
#  b'\t\t</ul>\n',
#  b'\t</li>\n',
#  b'\t<li id="toc-References"\n',
#  b'\t\tclass="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n',
#  b'\t\t<a class="vector-toc-link" href="#References">\n',
#  b'\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t<span class="vector-toc-numb">3</span>References</div>\n',
#  b'\t\t</a>\n',
#  b'\t\t\n',
#  b'\t\t<ul id="toc-References-sublist" class="vector-toc-list">\n',
#  b'\t\t</ul>\n',
#  b'\t</li>\n',
#  b'\t<li id="toc-External_links"\n',
#  b'\t\tclass="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n',
#  b'\t\t<a class="vector-toc-link" href="#External_links">\n',
#  b'\t\t\t<div class="vector-toc-text">\n',
#  b'\t\t\t<span class="vector-toc-numb">4</span>External links</div>\n',
#  b'\t\t</a>\n',
#  b'\t\t\n',
#  b'\t\t<ul id="toc-External_links-sublist" class="vector-toc-list">\n',
#  b'\t\t</ul>\n',
#  b'\t</li>\n',
#  b'</ul>\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t\t</div>\n',
#  b'</nav>\n',
#  b'\t\t\t\t<div class="mw-content-container">\n',
#  b'\t\t\t<main id="content" class="mw-body" role="main">\n',
#  b'\t\t\t\t<header class="mw-body-header vector-page-titlebar">\n',
#  b'\t\t\t\t\t<label\n',
#  b'\t\t\t\t\t\tid="vector-toc-collapsed-button"\n',
#  b'\t\t\t\t\t\tclass="mw-ui-button mw-ui-quiet mw-ui-icon mw-ui-icon-flush-left mw-ui-icon-element mw-ui-icon-wikimedia-listBullet mw-checkbox-hack-button"\n',
#  b'\t\t\t\t\t\tfor="vector-toc-collapsed-checkbox"\n',
#  b'\t\t\t\t\t\trole="button"\n',
#  b'\t\t\t\t\t\taria-controls="toc-toggle-list"\n',
#  b'\t\t\t\t\t\tdata-event-name="vector.toc-toggle-list"\n',
#  b'\t\t\t\t\t\ttabindex="0"\n',
#  b'\t\t\t\t\t\ttitle="Table of Contents">\n',
#  b'\t\t\t\t\t\tToggle the table of contents\n',
#  b'\t\t\t\t\t</label>\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t\t\t\n',
#  b'\t<div id="vector-page-titlebar-toc" class="vector-menu vector-dropdown vector-menu-dropdown vector-page-titlebar-toc mw-ui-icon-flush-left"  >\n',
#  b'\t\t<input type="checkbox"\n',
#  b'\t\t\tid="vector-page-titlebar-toc-checkbox"\n',
#  b'\t\t\trole="button"\n',
#  b'\t\t\taria-haspopup="true"\n',
#  b'\t\t\tdata-event-name="ui.dropdown-vector-page-titlebar-toc"\n',
#  b'\t\t\tclass="vector-menu-checkbox "\n',
#  b'\t\t\t\n',
#  b'\t\t\t\n',
#  b'\t\t/>\n',
#  b'\t\t<label\n',
#  b'\t\t\tid="vector-page-titlebar-toc-label"\n',
#  b'\t\t\tfor="vector-page-titlebar-toc-checkbox"\n',
#  b'\t\t\tclass="vector-menu-heading mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-wikimedia-listBullet"\n',
#  b'\t\t\t\n',
#  b'\t\t>\n',
#  b'\t\t\t<span class="vector-menu-heading-label"></span>\n',
#  b'\t\t</label>\n',
#  b'\t\t<div class="vector-menu-content">\n',
#  b'\t\n',
#  b'\t\t<div id="vector-page-titlebar-toc-unpinned-container" class="vector-unpinned-container">\n',
#  b'\t\t</div>\n',
#  b'\t\n',
#  b'\t\t</div>\n',
#  b'\t</div>\n',
#  b'\t\t\t\t    <h1 id="firstHeading" class="firstHeading mw-first-heading"><span class="mw-page-title-main">Healthcare in Europe</span></h1>\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t\t            \n',
#  b'<div id="p-lang-btn" class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-lang mw-ui-icon-flush-right"  >\n',
#  b'\t<input type="checkbox"\n',
#  b'\t\tid="p-lang-btn-checkbox"\n',
#  b'\t\trole="button"\n',
#  b'\t\taria-haspopup="true"\n',
#  b'\t\tdata-event-name="ui.dropdown-p-lang-btn"\n',
#  b'\t\tclass="vector-menu-checkbox mw-interlanguage-selector"\n',
#  b'\t\taria-label="Go to an article in another language. Available in 1 language"\n',
#  b'\t\t\n',
#  b'\t/>\n',
#  b'\t<label\n',
#  b'\t\tid="p-lang-btn-label"\n',
#  b'\t\tfor="p-lang-btn-checkbox"\n',
#  b'\t\tclass="vector-menu-heading mw-ui-button mw-ui-quiet mw-ui-progressive mw-portlet-lang-heading-1"\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="mw-ui-icon mw-ui-icon-wikimedia-language-progressive"></span><span class="vector-menu-heading-label">1 language</span>\n',
#  b'\t</label>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\n',
#  b'    <div class="vector-menu-content">\n',
#  b'        \n',
#  b'        <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-uk mw-list-item"><a href="https://uk.wikipedia.org/wiki/%D0%9E%D1%85%D0%BE%D1%80%D0%BE%D0%BD%D0%B0_%D0%B7%D0%B4%D0%BE%D1%80%D0%BE%D0%B2%E2%80%99%D1%8F_%D0%B2_%D0%84%D0%B2%D1%80%D0%BE%D0%BF%D1%96" title="\xd0\x9e\xd1\x85\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbd\xd0\xb0 \xd0\xb7\xd0\xb4\xd0\xbe\xd1\x80\xd0\xbe\xd0\xb2\xe2\x80\x99\xd1\x8f \xd0\xb2 \xd0\x84\xd0\xb2\xd1\x80\xd0\xbe\xd0\xbf\xd1\x96 \xe2\x80\x93 Ukrainian" lang="uk" hreflang="uk" class="interlanguage-link-target"><span>\xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\xd1\x97\xd0\xbd\xd1\x81\xd1\x8c\xd0\xba\xd0\xb0</span></a></li></ul>\n',
#  b'        <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q5691262#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>\n',
#  b'    </div>\n',
#  b'\n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\t\t\t\t</header>\n',
#  b'\t\t\t\t<div class="vector-page-toolbar">\n',
#  b'\t\t\t\t\t<div class="vector-page-toolbar-container">\n',
#  b'\t\t\t\t\t\t<div id="left-navigation">\n',
#  b'\t\t\t\t\t\t\t<nav aria-label="Namespaces">\n',
#  b'\t\t\t\t\t\t\t\t\n',
#  b'<div id="p-associated-pages" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages"  >\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="ca-nstab-main" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/Healthcare_in_Europe" title="View the content page [c]" accesskey="c"><span>Article</span></a></li><li id="ca-talk" class="vector-tab-noicon mw-list-item"><a href="/wiki/Talk:Healthcare_in_Europe" rel="discussion" title="Discuss improvements to the content page [t]" accesskey="t"><span>Talk</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t\t\t\t\t\t\t\n',
#  b'\n',
#  b'<div id="p-variants" class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-variants emptyPortlet"  >\n',
#  b'\t<input type="checkbox"\n',
#  b'\t\tid="p-variants-checkbox"\n',
#  b'\t\trole="button"\n',
#  b'\t\taria-haspopup="true"\n',
#  b'\t\tdata-event-name="ui.dropdown-p-variants"\n',
#  b'\t\tclass="vector-menu-checkbox"\n',
#  b'\t\taria-label="Change language variant"\n',
#  b'\t\t\n',
#  b'\t/>\n',
#  b'\t<label\n',
#  b'\t\tid="p-variants-label"\n',
#  b'\t\tfor="p-variants-checkbox"\n',
#  b'\t\tclass="vector-menu-heading "\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">English</span>\n',
#  b'\t</label>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'\n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\t\t\t\t\t\t\t</nav>\n',
#  b'\t\t\t\t\t\t</div>\n',
#  b'\t\t\t\t\t\t<div id="right-navigation" class="vector-collapsible">\n',
#  b'\t\t\t\t\t\t\t<nav aria-label="Views">\n',
#  b'\t\t\t\t\t\t\t\t\n',
#  b'<div id="p-views" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views"  >\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="ca-view" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/Healthcare_in_Europe"><span>Read</span></a></li><li id="ca-edit" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit" title="Edit this page [e]" accesskey="e"><span>Edit</span></a></li><li id="ca-history" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=history" title="Past revisions of this page [h]" accesskey="h"><span>View history</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\n',
#  b'\t\t\t\t\t\t\t</nav>\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t\t\t\t\t<nav class="vector-page-tools-landmark" aria-label="More options">\n',
#  b'\t\t\t\t\t\t\t\t\n',
#  b'\n',
#  b'<div id="p-cactions" class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items"  title="More options" >\n',
#  b'\t<input type="checkbox"\n',
#  b'\t\tid="p-cactions-checkbox"\n',
#  b'\t\trole="button"\n',
#  b'\t\taria-haspopup="true"\n',
#  b'\t\tdata-event-name="ui.dropdown-p-cactions"\n',
#  b'\t\tclass="vector-menu-checkbox"\n',
#  b'\t\t\n',
#  b'\t\t\n',
#  b'\t/>\n',
#  b'\t<label\n',
#  b'\t\tid="p-cactions-label"\n',
#  b'\t\tfor="p-cactions-checkbox"\n',
#  b'\t\tclass="vector-menu-heading"\n',
#  b'\t\t\n',
#  b'\t>\n',
#  b'\t\t<span class="vector-menu-heading-label">More</span>\n',
#  b'\t</label>\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\n',
#  b'\t<div class="vector-menu-content">\n',
#  b'\t    \n',
#  b'\t    <ul class="vector-menu-content-list"><li id="ca-more-view" class="selected vector-more-collapsible-item mw-list-item"><a href="/wiki/Healthcare_in_Europe"><span>Read</span></a></li><li id="ca-more-edit" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit"><span>Edit</span></a></li><li id="ca-more-history" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=history"><span>View history</span></a></li></ul>\n',
#  b'\t    \n',
#  b'\t</div>\n',
#  b'\n',
#  b'\t</div>\n',
#  b'</div>\n',
#  b'\t\t\t\t\t\t\t</nav>\n',
#  b'\t\t\t\t\t\t</div>\n',
#  b'\t\t\t\t\t</div>\n',
#  b'\t\t\t\t</div>\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t\t<div id="bodyContent" class="vector-body" aria-labelledby="firstHeading" data-mw-ve-target-container>\n',
#  b'\t\t\t\t\t<div class="vector-body-before-content">\n',
#  b'\t\t\t\t\t        <div class="mw-indicators">\n',
#  b'        </div>\n',
#  b'\n',
#  b'\t\t\t\t\t    <div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>\n',
#  b'\t\t\t\t\t</div>\n',
#  b'\t\t\t\t\t<div id="contentSub"><div id="mw-content-subtitle"></div></div>\n',
#  b'\t\t\t\t\t\n',
#  b'\t\t\t\t\t\n',
#  b'\t\t\t\t\t<div id="mw-content-text" class="mw-body-content mw-content-ltr" lang="en" dir="ltr"><div class="mw-parser-output"><style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div role="note" class="hatnote navigation-not-searchable">See also: <a href="/wiki/Universal_health_coverage_by_country" class="mw-redirect" title="Universal health coverage by country">Universal health coverage by country</a></div>\n',
#  b'<p class="mw-empty-elt">\n',
#  b'</p>\n',
#  b'<div class="thumb tright"><div class="thumbinner" style="width:222px;"><a href="/wiki/File:Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/220px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" decoding="async" width="220" height="138" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/330px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg/440px-Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg 2x" data-file-width="1000" data-file-height="626" /></a>  <div class="thumbcaption"><div class="magnify"><a href="/wiki/File:Carte_Europ%C3%A9enne_d%27Assurance_Maladie_France.jpg" class="internal" title="Enlarge"></a></div><a href="/wiki/European_Health_Insurance_Card" title="European Health Insurance Card">European Health Insurance Card</a> (French version pictured)</div></div></div>\n',
#  b'<p><b>Healthcare in Europe</b> is provided through a wide range of different systems run at individual <a href="/wiki/Nation" title="Nation">national</a> levels. Most European countries have a system of tightly regulated, competing private health insurance companies, with government subsidies available for citizens who cannot afford coverage.<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup><sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup> Many <a href="/wiki/Europe" title="Europe">European</a> countries (and all <a href="/wiki/European_Union" title="European Union">European Union</a> countries) offer their citizens a <a href="/wiki/European_Health_Insurance_Card" title="European Health Insurance Card">European Health Insurance Card</a> which, on a reciprocal basis, provides insurance for emergency medical treatment insurance when visiting other participating European countries.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">&#91;3&#93;</a></sup>\n',
#  b'</p>\n',
#  b'<meta property="mw:PageProp/toc" />\n',
#  b'<h2><span class="mw-headline" id="European_health">European health</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=1" title="Edit section: European health">edit</a><span class="mw-editsection-bracket">]</span></span></h2>\n',
#  b'<table class="wikitable floatright sortable" style="font-size: 90%">\n',
#  b'<caption style="font-size:100%">EU countries with the highest life expectancy (2019)<sup id="cite_ref-hdr-life-exp_4-0" class="reference"><a href="#cite_note-hdr-life-exp-4">&#91;4&#93;</a></sup>\n',
#  b'</caption>\n',
#  b'<tbody><tr>\n',
#  b'<th>World<br />Rank\n',
#  b'</th>\n',
#  b'<th>EU<br />Rank\n',
#  b'</th>\n',
#  b'<th>Country\n',
#  b'</th>\n',
#  b'<th colspan="3">Life expectancy<br />at birth (years)\n',
#  b'</th></tr>\n',
#  b'<tr>\n',
#  b'<td>5.\n',
#  b'</td>\n',
#  b'<td>1.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Spain" title="Spain">Spain</a>\n',
#  b'</td>\n',
#  b'<td>83.4\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>6.\n',
#  b'</td>\n',
#  b'<td>2.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Italy" title="Italy">Italy</a>\n',
#  b'</td>\n',
#  b'<td>83.4\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>11.\n',
#  b'</td>\n',
#  b'<td>3.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Sweden" title="Sweden">Sweden</a>\n',
#  b'</td>\n',
#  b'<td>82.7\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>12.\n',
#  b'</td>\n',
#  b'<td>4.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/France" title="France">France</a>\n',
#  b'</td>\n',
#  b'<td>82.5\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>13.\n',
#  b'</td>\n',
#  b'<td>5.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Malta" title="Malta">Malta</a>\n',
#  b'</td>\n',
#  b'<td>82.4\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>16.\n',
#  b'</td>\n',
#  b'<td>6.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Ireland" title="Ireland">Ireland</a>\n',
#  b'</td>\n',
#  b'<td>82.1\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>17.\n',
#  b'</td>\n',
#  b'<td>7.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Netherlands" title="Netherlands">Netherlands</a>\n',
#  b'</td>\n',
#  b'<td>82.1\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>19.\n',
#  b'</td>\n',
#  b'<td>8.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Luxembourg" title="Luxembourg">Luxembourg</a>\n',
#  b'</td>\n',
#  b'<td>82.1\n',
#  b'</td></tr>\n',
#  b'<tr>\n',
#  b'<td>20.\n',
#  b'</td>\n',
#  b'<td>9.\n',
#  b'</td>\n',
#  b'<td><a href="/wiki/Greece" title="Greece">Greece</a>\n',
#  b'</td>\n',
#  b'<td>82.1\n',
#  b'</td></tr>\n',
#  b'</tbody></table>\n',
#  b'<p>The <a href="/wiki/World_Health_Organization" title="World Health Organization">World Health Organization</a> has listed 53 countries as comprising the European region. Health outcomes vary greatly by country. Countries in western Europe have had a significant increase in life expectancy since World War II, while most of eastern Europe and the former Soviet countries have experienced a decrease in life expectancy.<sup id="cite_ref-lancet1_5-0" class="reference"><a href="#cite_note-lancet1-5">&#91;5&#93;</a></sup>\n',
#  b'</p><p><a href="/wiki/Tobacco" title="Tobacco">Tobacco</a> use is the largest preventable cause of death in Europe. Many countries have passed legislation in the past few decades restricting tobacco sales and use.<sup id="cite_ref-lancet1_5-1" class="reference"><a href="#cite_note-lancet1-5">&#91;5&#93;</a></sup> According to the European Health Interview Survey (EHIS) conducted between 2013 and 2015, substantial inequalities existed in terms of sex, age and education level concerning the proportion of adults who were daily smokers of cigarettes.<sup id="cite_ref-6" class="reference"><a href="#cite_note-6">&#91;6&#93;</a></sup>\n',
#  b'</p>\n',
#  b'<h3><span class="mw-headline" id="European_Union">European Union</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=2" title="Edit section: European Union">edit</a><span class="mw-editsection-bracket">]</span></span></h3>\n',
#  b'<p>The <a href="/wiki/European_Union" title="European Union">European Union</a> has no major administrative responsibility in the field of healthcare. The <a href="/wiki/European_Commission" title="European Commission">European Commission\'s</a> <a href="/wiki/Directorate-General_for_Health_and_Consumers" class="mw-redirect" title="Directorate-General for Health and Consumers">Directorate-General for Health and Consumers</a> however seeks to align national laws on the safety of food and other products, on consumers\' rights, and on the protection of people\'s health, to form new EU wide laws and thus strengthen its internal markets.<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">&#91;<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (January 2021)">citation needed</span></a></i>&#93;</sup>\n',
#  b'</p><p>Both the <a href="/wiki/World_Health_Organization" title="World Health Organization">World Health Organization</a> Regional Office for Europe (<a href="/wiki/List_of_WHO_regions#European_Region_(EURO)" title="List of WHO regions">WHO/Europe</a>) and the <a href="/wiki/European_Centre_for_Disease_Prevention_and_Control" title="European Centre for Disease Prevention and Control">European Centre for Disease Prevention and Control</a> are involved in public health development in Europe.<sup id="cite_ref-7" class="reference"><a href="#cite_note-7">&#91;7&#93;</a></sup>\n',
#  b'</p>\n',
#  b'<h3><span class="mw-headline" id="COVID-19_pandemic">COVID-19 pandemic</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=3" title="Edit section: COVID-19 pandemic">edit</a><span class="mw-editsection-bracket">]</span></span></h3>\n',
#  b'<p>The <a href="/wiki/European_Union" title="European Union">European Union</a> countries were impacted by the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>. The governments of the various countries adopted healthcare standards aimed at the number of <a href="/wiki/Infection" title="Infection">infected</a> and people who are deceased. A widespread vaccination campaign helped to lower the COVID-19 <a href="/wiki/Mortality_rate" title="Mortality rate">mortality rate</a>. In addition to the <a href="/wiki/COVID-19_vaccines" class="mw-redirect" title="COVID-19 vaccines">COVID-19 vaccines</a>, the mortality rates were determined by the number of <a href="/wiki/Physicians" class="mw-redirect" title="Physicians">physicians</a>, the number of available <a href="/wiki/Intensive_care_unit" title="Intensive care unit">Intensive care unit</a> (ICU) beds and safety policies carried out by governments. Mortality rates varied in Europe depending on whether the countries have a higher or lower rate of the adult population over 65 years of age. Studies show that having an adequate number of <a href="/wiki/Health_professionals" class="mw-redirect" title="Health professionals">health professionals</a> is one of the most important variables in reducing the number of deaths.<sup id="cite_ref-8" class="reference"><a href="#cite_note-8">&#91;8&#93;</a></sup>\n',
#  b'</p>\n',
#  b'<h4><span class="mw-headline" id="Response">Response</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Healthcare_in_Europe&amp;action=edit&amp;section=4" title="Edit section: Response">edit</a><span class="mw-editsection-bracket">]</span></span></h4>\n',
#  b'<p>The emergence of the <a href="/wiki/Coronavirus" title="Coronavirus">Coronavirus</a> has upended life as we know it in various <a href="/wiki/European_Union" title="European Union">European Union</a> countries. In responding to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, <a href="/wiki/Public_health" title="Public health">public health</a> infrastructures and resources, governmental, and cultural values all play a key role in stopping the threat. Finding an approach that balances effectiveness, efficiency, and successful response to the pandemic is the key to ending the crisis.\n',
#  b'</p><p>European Union countries like <a href="/wiki/Greece" title="Greece">Greece</a> and <a href="/wiki/Sweden" title="Sweden">Sweden</a> have similar populations and sizes. They have a difficult cultural and political stance. The government response of various European countries to the pandemic was to stay home and slow down the spread of the virus. It was proactive in closing businesses and stores early on and even before the first COVID-19 death. The governmental response including the banning of all <a href="/wiki/International_non-essential_travel" title="International non-essential travel">international non-essential travel</a> and <a href="/wiki/COVID-19_lockdowns" title="COVID-19 lockdowns">COVID-19 lockdowns</a> helped to keep the death toll to a minimum.<sup id="cite_ref-9" class="reference"><a href="#cite_note-9">&#91;9&#93;</a></sup>\n',
# ...
#  b'<ul><li><a href="/wiki/List_of_hospitals_in_Albania" title="List of hospitals in Albania">Albania</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Andorra" class="mw-redirect" title="List of hospitals in Andorra">Andorra</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Armenia" title="List of hospitals in Armenia">Armenia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Austria" title="List of hospitals in Austria">Austria</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Azerbaijan" title="List of hospitals in Azerbaijan">Azerbaijan</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Belarus" title="List of hospitals in Belarus">Belarus</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Belgium" title="List of hospitals in Belgium">Belgium</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Bosnia_and_Herzegovina" title="List of hospitals in Bosnia and Herzegovina">Bosnia and Herzegovina</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Bulgaria" title="List of hospitals in Bulgaria">Bulgaria</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Croatia" title="List of hospitals in Croatia">Croatia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Cyprus" title="List of hospitals in Cyprus">Cyprus</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Czech_Republic" title="List of hospitals in the Czech Republic">Czech Republic</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Denmark" title="List of hospitals in Denmark">Denmark</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Estonia" title="List of hospitals in Estonia">Estonia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Finland" title="List of hospitals in Finland">Finland</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_France" title="List of hospitals in France">France</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Georgia_(country)" class="mw-redirect" title="List of hospitals in Georgia (country)">Georgia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Germany" title="List of hospitals in Germany">Germany</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Greece" title="List of hospitals in Greece">Greece</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Hungary" title="List of hospitals in Hungary">Hungary</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Iceland" class="mw-redirect" title="List of hospitals in Iceland">Iceland</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Republic_of_Ireland" title="List of hospitals in the Republic of Ireland">Ireland</a></li>\n',
#  b'<li class="mw-empty-elt"></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Italy" title="List of hospitals in Italy">Italy</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Kazakhstan" class="mw-redirect" title="List of hospitals in Kazakhstan">Kazakhstan</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Latvia" title="List of hospitals in Latvia">Latvia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Liechtenstein" class="mw-redirect" title="List of hospitals in Liechtenstein">Liechtenstein</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Lithuania" title="List of hospitals in Lithuania">Lithuania</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Luxembourg" title="List of hospitals in Luxembourg">Luxembourg</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Malta" title="List of hospitals in Malta">Malta</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Moldova" class="mw-redirect" title="List of hospitals in Moldova">Moldova</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Monaco" class="mw-redirect" title="List of hospitals in Monaco">Monaco</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Montenegro" class="mw-redirect" title="List of hospitals in Montenegro">Montenegro</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Netherlands" title="List of hospitals in the Netherlands">Netherlands</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_North_Macedonia" class="mw-redirect" title="List of hospitals in North Macedonia">North Macedonia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Norway" title="List of hospitals in Norway">Norway</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Poland" title="List of hospitals in Poland">Poland</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Portugal" class="mw-redirect" title="List of hospitals in Portugal">Portugal</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Romania" title="List of hospitals in Romania">Romania</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Russia" title="List of hospitals in Russia">Russia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_San_Marino" class="mw-redirect" title="List of hospitals in San Marino">San Marino</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Serbia" title="List of hospitals in Serbia">Serbia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Slovakia" title="List of hospitals in Slovakia">Slovakia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Slovenia" title="List of hospitals in Slovenia">Slovenia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Spain" title="List of hospitals in Spain">Spain</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Sweden" title="List of hospitals in Sweden">Sweden</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Switzerland" title="List of hospitals in Switzerland">Switzerland</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Turkey" title="List of hospitals in Turkey">Turkey</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Ukraine" title="List of hospitals in Ukraine">Ukraine</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_United_Kingdom" title="List of hospitals in the United Kingdom">United Kingdom</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Vatican_City" class="mw-redirect" title="List of hospitals in Vatican City">Vatican City</a></li></ul>\n',
#  b'</div></td></tr><tr><th scope="row" class="navbox-group" style="width:1%">States with limited<br />recognition</th><td class="navbox-list-with-group navbox-list navbox-even hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">\n',
#  b'<ul><li><a href="/wiki/List_of_hospitals_in_Abkhazia" class="mw-redirect" title="List of hospitals in Abkhazia">Abkhazia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Republic_of_Artsakh" class="mw-redirect" title="List of hospitals in the Republic of Artsakh">Artsakh</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Kosovo" class="mw-redirect" title="List of hospitals in Kosovo">Kosovo</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Northern_Cyprus" class="mw-redirect" title="List of hospitals in Northern Cyprus">Northern Cyprus</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_South_Ossetia" class="mw-redirect" title="List of hospitals in South Ossetia">South Ossetia</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Transnistria" class="mw-redirect" title="List of hospitals in Transnistria">Transnistria</a></li></ul>\n',
#  b'</div></td></tr><tr><th scope="row" class="navbox-group" style="width:1%">Dependencies and<br />other entities</th><td class="navbox-list-with-group navbox-list navbox-odd hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">\n',
#  b'<ul><li><a href="/wiki/List_of_hospitals_in_%C3%85land" class="mw-redirect" title="List of hospitals in \xc3\x85land">\xc3\x85land</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Faroe_Islands" class="mw-redirect" title="List of hospitals in the Faroe Islands">Faroe Islands</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Gibraltar" class="mw-redirect" title="List of hospitals in Gibraltar">Gibraltar</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Guernsey" class="mw-redirect" title="List of hospitals in Guernsey">Guernsey</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_the_Isle_of_Man" class="mw-redirect" title="List of hospitals in the Isle of Man">Isle of Man</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Jersey" title="List of hospitals in Jersey">Jersey</a></li>\n',
#  b'<li><a href="/wiki/List_of_hospitals_in_Svalbard" class="mw-redirect" title="List of hospitals in Svalbard">Svalbard</a></li></ul>\n',
#  b'</div></td></tr></tbody></table></div>\n',
#  b'<div class="navbox-styles"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1061467846"/></div><div role="navigation" class="navbox authority-control" aria-label="Navbox" style="padding:3px"><table class="nowraplinks hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="row" class="navbox-group" style="width:1%"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a>: National libraries <a href="https://www.wikidata.org/wiki/Q5691262#identifiers" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" decoding="async" width="10" height="10" style="vertical-align: text-top" class="noprint" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" data-file-width="20" data-file-height="20" /></a></th><td class="navbox-list-with-group navbox-list navbox-odd" style="width:100%;padding:0"><div style="padding:0 0.25em">\n',
#  b'<ul><li><span class="uid"><a rel="nofollow" class="external text" href="https://id.loc.gov/authorities/subjects/sh2010101166">United States</a></span></li></ul>\n',
#  b'</div></td></tr></tbody></table></div>\n',
#  b'<!-- \n',
#  b'NewPP limit report\n',
#  b'Parsed by mw2412\n',
#  b'Cached time: 20230118030825\n',
#  b'Cache expiry: 1814400\n',
#  b'Reduced expiry: false\n',
#  b'Complications: [vary\xe2\x80\x90revision\xe2\x80\x90sha1, show\xe2\x80\x90toc]\n',
#  b'CPU time usage: 0.629 seconds\n',
#  b'Real time usage: 0.750 seconds\n',
#  b'Preprocessor visited node count: 33691/1000000\n',
#  b'Post\xe2\x80\x90expand include size: 129501/2097152 bytes\n',
#  b'Template argument size: 18989/2097152 bytes\n',
#  b'Highest expansion depth: 15/100\n',
#  b'Expensive parser function count: 17/500\n',
#  b'Unstrip recursion depth: 1/20\n',
#  b'Unstrip post\xe2\x80\x90expand size: 75437/5000000 bytes\n',
#  b'Lua time usage: 0.267/10.000 seconds\n',
#  b'Lua memory usage: 7477159/52428800 bytes\n',
#  b'Number of Wikibase entities loaded: 1/400\n',
#  b'-->\n',
#  b'<!--\n',
#  b'Transclusion expansion time report (%,ms,calls,template)\n',
#  b'100.00%  656.100      1 -total\n',
#  b' 56.14%  368.334      3 Template:Navbox\n',
#  b' 39.83%  261.348    147 Template:Iso2country\n',
#  b' 32.10%  210.619      2 Template:Europe_in_topic\n',
#  b' 25.83%  169.485      1 Template:Health_care_in_Europe\n',
#  b' 25.38%  166.505      1 Template:Europe_topic\n',
#  b' 20.01%  131.287      1 Template:Reflist\n',
#  b' 12.87%   84.459      9 Template:Cite_web\n',
#  b' 11.79%   77.335    147 Template:Iso2country/data\n',
#  b'  5.73%   37.578      2 Template:Fix\n',
#  b'-->\n',
#  b'\n',
#  b'<!-- Saved in parser cache with key enwiki:pcache:idhash:15973120-0!canonical and timestamp 20230118030825 and revision id 1131475728.\n',
#  b' -->\n',
#  b'</div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript>\n',
#  b'<div class="printfooter" data-nosnippet="">Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728">https://en.wikipedia.org/w/index.php?title=Healthcare_in_Europe&amp;oldid=1131475728</a>"</div></div>\n',
#  b'\t\t\t\t\t<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Health_in_Europe" title="Category:Health in Europe">Health in Europe</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:CS1_maint:_url-status" title="Category:CS1 maint: url-status">CS1 maint: url-status</a></li><li><a href="/wiki/Category:Use_dmy_dates_from_December_2021" title="Category:Use dmy dates from December 2021">Use dmy dates from December 2021</a></li><li><a href="/wiki/Category:All_articles_with_unsourced_statements" title="Category:All articles with unsourced statements">All articles with unsourced statements</a></li><li><a href="/wiki/Category:Articles_with_unsourced_statements_from_January_2021" title="Category:Articles with unsourced statements from January 2021">Articles with unsourced statements from January 2021</a></li><li><a href="/wiki/Category:Articles_with_unsourced_statements_from_September_2022" title="Category:Articles with unsourced statements from September 2022">Articles with unsourced statements from September 2022</a></li><li><a href="/wiki/Category:Articles_with_LCCN_identifiers" title="Category:Articles with LCCN identifiers">Articles with LCCN identifiers</a></li></ul></div></div>\n',
#  b'\t\t\t\t\t\n',
#  b'\t\t\t\t</div>\n',
#  b'\t\t\t\t\n',
#  b'\t\t\t</main>\n',
#  b'\t\t\t\n',
#  b'\t\t</div>\n',
#  b'\t\t<div class="mw-footer-container">\n',
#  b'\t\t\t\n',
#  b'<footer id="footer" class="mw-footer" role="contentinfo" >\n',
#  b'\t<ul id="footer-info">\n',
#  b'\t<li id="footer-info-lastmod"> This page was last edited on 4 January 2023, at 09:32<span class="anonymous-show">&#160;(UTC)</span>.</li>\n',
#  b'\t<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License 3.0</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;\n',
#  b'additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia\xc2\xae is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>\n',
#  b'</ul>\n',
#  b'\n',
#  b'\t<ul id="footer-places">\n',
#  ...]

# %%
lst
# Out:
# ['b\'<table class="wikitable floatright sortable" style="font-size: 90%">\\n\'',
#  'b\'<div class="navbox-styles"><style data-mw-deduplicate="TemplateStyles:r1129693374">.mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" \\xc2\\xb7 ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-parser-output .hlist li:last-child::after{content:none}.mw-parser-output .hlist dd dd:first-child::before,.mw-parser-output .hlist dd dt:first-child::before,.mw-parser-output .hlist dd li:first-child::before,.mw-parser-output .hlist dt dd:first-child::before,.mw-parser-output .hlist dt dt:first-child::before,.mw-parser-output .hlist dt li:first-child::before,.mw-parser-output .hlist li dd:first-child::before,.mw-parser-output .hlist li dt:first-child::before,.mw-parser-output .hlist li li:first-child::before{content:" (";font-weight:normal}.mw-parser-output .hlist dd dd:last-child::after,.mw-parser-output .hlist dd dt:last-child::after,.mw-parser-output .hlist dd li:last-child::after,.mw-parser-output .hlist dt dd:last-child::after,.mw-parser-output .hlist dt dt:last-child::after,.mw-parser-output .hlist dt li:last-child::after,.mw-parser-output .hlist li dd:last-child::after,.mw-parser-output .hlist li dt:last-child::after,.mw-parser-output .hlist li li:last-child::after{content:")";font-weight:normal}.mw-parser-output .hlist ol{counter-reset:listitem}.mw-parser-output .hlist ol>li{counter-increment:listitem}.mw-parser-output .hlist ol>li::before{content:" "counter(listitem)"\\\\a0 "}.mw-parser-output .hlist dd ol>li:first-child::before,.mw-parser-output .hlist dt ol>li:first-child::before,.mw-parser-output .hlist li ol>li:first-child::before{content:" ("counter(listitem)"\\\\a0 "}</style><style data-mw-deduplicate="TemplateStyles:r1061467846">.mw-parser-output .navbox{box-sizing:border-box;border:1px solid #a2a9b1;width:100%;clear:both;font-size:88%;text-align:center;padding:1px;margin:1em auto 0}.mw-parser-output .navbox .navbox{margin-top:0}.mw-parser-output .navbox+.navbox,.mw-parser-output .navbox+.navbox-styles+.navbox{margin-top:-1px}.mw-parser-output .navbox-inner,.mw-parser-output .navbox-subgroup{width:100%}.mw-parser-output .navbox-group,.mw-parser-output .navbox-title,.mw-parser-output .navbox-abovebelow{padding:0.25em 1em;line-height:1.5em;text-align:center}.mw-parser-output .navbox-group{white-space:nowrap;text-align:right}.mw-parser-output .navbox,.mw-parser-output .navbox-subgroup{background-color:#fdfdfd}.mw-parser-output .navbox-list{line-height:1.5em;border-color:#fdfdfd}.mw-parser-output .navbox-list-with-group{text-align:left;border-left-width:2px;border-left-style:solid}.mw-parser-output tr+tr>.navbox-abovebelow,.mw-parser-output tr+tr>.navbox-group,.mw-parser-output tr+tr>.navbox-image,.mw-parser-output tr+tr>.navbox-list{border-top:2px solid #fdfdfd}.mw-parser-output .navbox-title{background-color:#ccf}.mw-parser-output .navbox-abovebelow,.mw-parser-output .navbox-group,.mw-parser-output .navbox-subgroup .navbox-title{background-color:#ddf}.mw-parser-output .navbox-subgroup .navbox-group,.mw-parser-output .navbox-subgroup .navbox-abovebelow{background-color:#e6e6ff}.mw-parser-output .navbox-even{background-color:#f7f7f7}.mw-parser-output .navbox-odd{background-color:transparent}.mw-parse ...
#  'b\'<div class="navbox-styles"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1061467846"/></div><div role="navigation" class="navbox" aria-labelledby="Health_in_Europe" style="padding:3px"><table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="col" class="navbox-title" colspan="2"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1063604349"/><div class="navbar plainlinks hlist navbar-mini"><ul><li class="nv-view"><a href="/wiki/Template:Europe_topic" title="Template:Europe topic"><abbr title="View this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:Europe_topic" title="Template talk:Europe topic"><abbr title="Discuss this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">t</abbr></a></li><li class="nv-edit"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:Europe_topic&amp;action=edit"><abbr title="Edit this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">e</abbr></a></li></ul></div><div id="Health_in_Europe" style="font-size:114%;margin:0 4em"><a href="/wiki/Health_in_Europe" class="mw-redirect" title="Health in Europe">Health in Europe </a></div></th></tr><tr><th scope="row" class="navbox-group" style="width:1%">Sovereign states</th><td class="navbox-list-with-group navbox-list navbox-odd hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">\\n\'',
#  'b\'<div class="navbox-styles"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1061467846"/></div><div role="navigation" class="navbox" aria-labelledby="List_of_hospitals_in_Europe" style="padding:3px"><table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="col" class="navbox-title" colspan="2"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1063604349"/><div class="navbar plainlinks hlist navbar-mini"><ul><li class="nv-view"><a href="/wiki/Template:Europe_topic" title="Template:Europe topic"><abbr title="View this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:Europe_topic" title="Template talk:Europe topic"><abbr title="Discuss this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">t</abbr></a></li><li class="nv-edit"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:Europe_topic&amp;action=edit"><abbr title="Edit this template" style=";;background:none transparent;border:none;box-shadow:none;padding:0;">e</abbr></a></li></ul></div><div id="List_of_hospitals_in_Europe" style="font-size:114%;margin:0 4em"><a href="/wiki/List_of_hospitals_in_Europe" class="mw-redirect" title="List of hospitals in Europe">List of hospitals in Europe </a></div></th></tr><tr><th scope="row" class="navbox-group" style="width:1%">Sovereign states</th><td class="navbox-list-with-group navbox-list navbox-odd hlist" style="width:100%;padding:0"><div style="padding:0 0.25em">\\n\'',
#  'b\'<div class="navbox-styles"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1129693374"/><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1061467846"/></div><div role="navigation" class="navbox authority-control" aria-label="Navbox" style="padding:3px"><table class="nowraplinks hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="row" class="navbox-group" style="width:1%"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a>: National libraries <a href="https://www.wikidata.org/wiki/Q5691262#identifiers" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" decoding="async" width="10" height="10" style="vertical-align: text-top" class="noprint" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" data-file-width="20" data-file-height="20" /></a></th><td class="navbox-list-with-group navbox-list navbox-odd" style="width:100%;padding:0"><div style="padding:0 0.25em">\\n\'']

# %%
table=HCE.find('table',{'class','wikitable floatright sortable'})

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
x=lst[0]
extr=re.findall('"([^"]*)"',x)
table=HCE.find('table',{'class', extr[0]})

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
headers=[header.text for header in table.find_all('th')]
headers
# Out:
# ['WorldRank\n', 'EURank\n', 'Country\n', 'Life expectancyat birth (years)\n']

# %%
rows=[]
for row in table.find_all('tr'):
    rows.append([val.text.encode('utf8').decode() for val in row.find_all('td')])

# %%
df1=pd.DataFrame(rows, columns=headers)

# %%
df1.head(10)
# Out:
#    WorldRank  EURank      Country  Life expectancyat birth (years)
# 1        5.0     1.0        Spain                             83.4
# 2        6.0     2.0        Italy                             83.4
# 3       11.0     3.0       Sweden                             82.7
# 4       12.0     4.0       France                             82.5
# 5       13.0     5.0        Malta                             82.4
# 6       16.0     6.0      Ireland                             82.1
# 7       17.0     7.0  Netherlands                             82.1
# 8       19.0     8.0   Luxembourg                             82.1
# 9       20.0     9.0       Greece                             82.1

# %% [markdown]
# ## Health Expenditure

# %%
url='https://en.wikipedia.org/wiki/List_of_countries_by_total_health_expenditure_per_capita'
r=requests.get(url)
HEE=BeautifulSoup(r.text)
webpage=urllib2.urlopen(url)
htmlpage=webpage.readlines()
lst=[]
for line in htmlpage:
    line = str(line).rstrip()
    if re.search('table class', line):
        lst.append(line)
x=lst[1]
print(x)
extr=re.findall('"([^"]*)"', x)
table=HEE.find('table', {'class', extr[0]})
headers=[header.text for header in table.find_all('th')]
rows=[]
for row  in table.find_all('tr'):
    rows.append([val.text.encode('utf8').decode() for val in row.find_all('td')])
headers=[i.replace("\n","") for i in headers]
df2=pd.DataFrame(rows, columns=headers)

# %%
df2.head(10)
# Out:
#    Location  2018  2019  2020    2021
# 2   Austria  5519  5624  5883  6693.0
# 4    Canada  5308  5190  5828  5905.0
# 5     Chile  2281  2297  2413  2608.0
# 9   Denmark  5307  5360  5694  6384.0
# 10  Estonia  2364  2452  2729  2989.0
# 12   France  5099  5168  5468  6115.0
# 13  Germany  6282  6408  6939  7383.0
# 16  Iceland  4236  4318  4620  5096.0
# 17  Ireland  4871  4947  5373  5836.0
# 19    Italy  3496  3565  3747  4038.0

# %%
def preproc(dat):
    dat.dropna(axis=0, how='all', inplace=True)
    dat.columns=dat.columns.str.replace('\n','')
    dat.replace(['\n'], [''], regex=True, inplace=True)
    dat.replace([r'\s\*$'],[''], regex=True, inplace=True)
    dat.replace([','],[''], regex=True, inplace=True)
    dat.replace(r'\b[a-zA-Z]\b', np.nan, regex=True, inplace=True)
    dat.replace([r'^\s'],[''], regex=True,  inplace=True)
    dat=dat.apply(pd.to_numeric, errors='ignore')
    return(dat)

# %%
df1=preproc(df1)
df2=preproc(df2)

# %%
df1
# Out:
#    WorldRank  EURank      Country  Life expectancyat birth (years)
# 1        5.0     1.0        Spain                             83.4
# 2        6.0     2.0        Italy                             83.4
# 3       11.0     3.0       Sweden                             82.7
# 4       12.0     4.0       France                             82.5
# 5       13.0     5.0        Malta                             82.4
# 6       16.0     6.0      Ireland                             82.1
# 7       17.0     7.0  Netherlands                             82.1
# 8       19.0     8.0   Luxembourg                             82.1
# 9       20.0     9.0       Greece                             82.1

# %%
df2
# Out:
#           Location   2018   2019   2020     2021
# 2          Austria   5519   5624   5883   6693.0
# 4           Canada   5308   5190   5828   5905.0
# 5            Chile   2281   2297   2413   2608.0
# 9          Denmark   5307   5360   5694   6384.0
# 10         Estonia   2364   2452   2729   2989.0
# 12          France   5099   5168   5468   6115.0
# 13         Germany   6282   6408   6939   7383.0
# 16         Iceland   4236   4318   4620   5096.0
# 17         Ireland   4871   4947   5373   5836.0
# 19           Italy   3496   3565   3747   4038.0
# 21          Latvia   3079   3277   3582   3914.0
# 23      Luxembourg   2397   2682   2882   3309.0
# 26     New Zealand   5482   5644   6180   6753.0
# 28          Poland   6495   6476   6582   7065.0
# 29        Portugal   2107   2232   2286   2568.0
# 30        Slovakia   3134   3224   3348   3816.0
# 32     South Korea   3045   3222   3474   3737.0
# 34          Sweden   5419   5388   5757   6262.0
# 37  United Kingdom   4190   4386   5019   5387.0
# 38   United States  10451  10856  11859  12318.0

# %%
print(df1.isnull().sum().sum())
print(df2.isnull().sum().sum())
# Out:
# 0
# 0

# %%
df1[df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [WorldRank, EURank, Country, Life expectancyat birth (years)]
# Index: []

# %%
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Location, 2018, 2019, 2020, 2021]
# Index: []

# %%
df1.dropna(axis=0, how='any', inplace=True)

# %%
df2.dropna(axis=0, how='any', inplace=True)

# %%
df1.dtypes
# Out:
# WorldRank                          float64
# EURank                             float64
# Country                             object
# Life expectancyat birth (years)    float64
# dtype: object

# %%
df2.dtypes
# Out:
# Location     object
# 2018          int64
# 2019          int64
# 2020          int64
# 2021        float64
# dtype: object

# %%
df1.columns=['WorldRank', 'EURank', 'Country', 'Life expectancy in birth (years)']
df2.columns=['Country','2018', '2019', '2020','2021']

# %%
df1.head(10)
# Out:
#    WorldRank  EURank      Country  Life expectancy in birth (years)
# 1        5.0     1.0        Spain                              83.4
# 2        6.0     2.0        Italy                              83.4
# 3       11.0     3.0       Sweden                              82.7
# 4       12.0     4.0       France                              82.5
# 5       13.0     5.0        Malta                              82.4
# 6       16.0     6.0      Ireland                              82.1
# 7       17.0     7.0  Netherlands                              82.1
# 8       19.0     8.0   Luxembourg                              82.1
# 9       20.0     9.0       Greece                              82.1

# %%
df2.head(10)
# Out:
#     Country  2018  2019  2020    2021
# 2   Austria  5519  5624  5883  6693.0
# 4    Canada  5308  5190  5828  5905.0
# 5     Chile  2281  2297  2413  2608.0
# 9   Denmark  5307  5360  5694  6384.0
# 10  Estonia  2364  2452  2729  2989.0
# 12   France  5099  5168  5468  6115.0
# 13  Germany  6282  6408  6939  7383.0
# 16  Iceland  4236  4318  4620  5096.0
# 17  Ireland  4871  4947  5373  5836.0
# 19    Italy  3496  3565  3747  4038.0

# %% [markdown]
# ### Merging different Data

# %%
pd.merge(df1, df2, how='left', on='Country').head()
# Out:
#    WorldRank  EURank Country  Life expectancy in birth (years)    2018  \
# 0        5.0     1.0   Spain                              83.4     NaN
# 1        6.0     2.0   Italy                              83.4  3496.0
# 2       11.0     3.0  Sweden                              82.7  5419.0
# 3       12.0     4.0  France                              82.5  5099.0
# 4       13.0     5.0   Malta                              82.4     NaN
#
#      2019    2020    2021
# 0     NaN     NaN     NaN
# 1  3565.0  3747.0  4038.0
# 2  5388.0  5757.0  6262.0
# 3  5168.0  5468.0  6115.0
# 4     NaN     NaN     NaN

# %%
d1={'xx':10,'yy':20,'zz':30}

# %%
d1
# Out:
# {'xx': 10, 'yy': 20, 'zz': 30}
